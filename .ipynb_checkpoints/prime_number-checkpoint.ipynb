# %%
from matplotlib import pyplot as plt

x = []
y = []
power = 4

for i in range(1 , 100000):
    x.insert(i , i)

for i in range(1 , 100000):
    z = pow(i , power)
    y.insert(i , z)

plt.title(f"Graph of X^{power}")
plt.plot(x , y)
plt.show()
